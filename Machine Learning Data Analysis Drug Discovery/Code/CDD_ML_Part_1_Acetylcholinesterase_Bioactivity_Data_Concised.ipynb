# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in c:\users\orippee\appdata\local\anaconda3\lib\site-packages (0.10.9)
# Requirement already satisfied: urllib3 in c:\users\orippee\appdata\local\anaconda3\lib\site-packages (from chembl_webresource_client) (2.5.0)
# Requirement already satisfied: requests>=2.18.4 in c:\users\orippee\appdata\local\anaconda3\lib\site-packages (from chembl_webresource_client) (2.32.5)
# Requirement already satisfied: requests-cache~=1.2 in c:\users\orippee\appdata\local\anaconda3\lib\site-packages (from chembl_webresource_client) (1.3.1)
# Requirement already satisfied: easydict in c:\users\orippee\appdata\local\anaconda3\lib\site-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: attrs>=21.2 in c:\users\orippee\appdata\local\anaconda3\lib\site-packages (from requests-cache~=1.2->chembl_webresource_client) (25.4.0)
# Requirement already satisfied: cattrs>=22.2 in c:\users\orippee\appdata\local\anaconda3\lib\site-packages (from requests-cache~=1.2->chembl_webresource_client) (25.3.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\orippee\appdata\local\anaconda3\lib\site-packages (from requests-cache~=1.2->chembl_webresource_client) (4.5.0)
# Requirement already satisfied: url-normalize>=2.0 in c:\users\orippee\appdata\local\anaconda3\lib\site-packages (from requests-cache~=1.2->chembl_webresource_client) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.14.0 in c:\users\orippee\appdata\local\anaconda3\lib\site-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\orippee\appdata\local\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\orippee\appdata\local\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\orippee\appdata\local\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (2025.11.12)

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client
# Out:
# C:\Users\ORippee\AppData\Local\anaconda3\Lib\site-packages\chembl_webresource_client\__init__.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __version__ = __import__('pkg_resources').get_distribution('chembl_webresource_client').version

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Acetylcholinesterase**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('acetylcholinesterase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#    cross_references                   organism  \
# 0                []    Drosophila melanogaster
# 1                []               Homo sapiens
# 2                []        Torpedo californica
# 3                []               Mus musculus
# 4                []          Rattus norvegicus
# 5                []   Electrophorus electricus
# 6                []                 Bos taurus
# 7                []          Anopheles gambiae
# 8                []             Bemisia tabaci
# 9                []  Leptinotarsa decemlineata
# 10               []     Nephotettix cincticeps
# 11               []              Gallus gallus
# 12               []                Danio rerio
# 13               []              Aedes aegypti
# 14               []               Homo sapiens
# 15               []            Musca domestica
# 16               []        Plutella xylostella
# 17               []            Musca domestica
# 18               []  Pediculus humanus capitis
# 19               []          Spodoptera litura
# 20               []      Laodelphax striatella
# 21               []        Schizaphis graminum
# 22               []               Homo sapiens
# 23               []          Rattus norvegicus
# 24               []     Caenorhabditis elegans
# 25               []             Equus caballus
# 26               []             Equus caballus
# 27               []     Canis lupus familiaris
# 28               []               Mus musculus
# 29               []          Rattus norvegicus
# 30               []               Homo sapiens
#
#                                             pref_name  score  \
# 0                                Acetylcholinesterase   18.0
# 1                                Acetylcholinesterase   16.0
# 2                                Acetylcholinesterase   16.0
# 3                                Acetylcholinesterase   16.0
# 4                                Acetylcholinesterase   16.0
# 5                                Acetylcholinesterase   16.0
# 6                                Acetylcholinesterase   16.0
# 7                                Acetylcholinesterase   16.0
# 8                                               AChE2   16.0
# 9                                Acetylcholinesterase   16.0
# 10               Ace-orthologous acetylcholinesterase   16.0
# 11                               Acetylcholinesterase   16.0
# 12                               Acetylcholinesterase   16.0
# 13                               Acetylcholinesterase   16.0
# 14                                       Protein CutA   16.0
# 15                               Acetylcholinesterase   15.0
# 16                               Acetylcholinesterase   15.0
# 17                               Acetylcholinesterase   15.0
# 18                               Acetylcholinesterase   15.0
# 19                               Acetylcholinesterase   15.0
# 20                               Acetylcholinesterase   15.0
# 21                               Acetylcholinesterase   15.0
# 22                       Cholinesterases; ACHE & BCHE   14.0
# 23  Acetylcholinesterase and butyrylcholinesterase...   14.0
# 24                             Acetylcholinesterase 1   14.0
# 25                              Butyrylcholinesterase   11.0
# 26                                     Cholinesterase   11.0
# 27                                     Cholinesterase   11.0
# 28                                     Cholinesterase   10.0
# 29                              Butyrylcholinesterase   10.0
# 30                                     Cholinesterase    5.0
#
#     species_group_flag target_chembl_id  \
# 0                False    CHEMBL2242744
# 1                False        CHEMBL220
# 2                False       CHEMBL4780
# 3                False       CHEMBL3198
# 4                False       CHEMBL3199
# 5                False       CHEMBL4078
# 6                False       CHEMBL4768
# 7                False    CHEMBL2046266
# 8                False    CHEMBL2366409
# 9                False    CHEMBL2366490
# 10               False    CHEMBL2366514
# 11               False    CHEMBL3227914
# 12               False    CHEMBL3308995
# 13               False    CHEMBL4295607
# 14               False    CHEMBL6067022
# 15               False       CHEMBL5752
# 16               False    CHEMBL2242729
# 17               False    CHEMBL2242743
# 18               False    CHEMBL2362988
# 19               False    CHEMBL2366422
# 20               False    CHEMBL2366446
# 21               False    CHEMBL2366511
# 22               False    CHEMBL2095233
# 23               False    CHEMBL2111475
# 24               False    CHEMBL3341583
# 25               False       CHEMBL5077
# 26               False       CHEMBL5763
# 27               False    CHEMBL4630814
# 28               False       CHEMBL2528
# 29               False       CHEMBL3403
# 30               False       CHEMBL1914
#
#                                     target_components        target_type  \
# 0   [{'accession': 'P07140', 'component_descriptio...     SINGLE PROTEIN
# 1   [{'accession': 'P22303', 'component_descriptio...     SINGLE PROTEIN
# 2   [{'accession': 'P04058', 'component_descriptio...     SINGLE PROTEIN
# 3   [{'accession': 'P21836', 'component_descriptio...     SINGLE PROTEIN
# 4   [{'accession': 'P37136', 'component_descriptio...     SINGLE PROTEIN
# 5   [{'accession': 'O42275', 'component_descriptio...     SINGLE PROTEIN
# 6   [{'accession': 'P23795', 'component_descriptio...     SINGLE PROTEIN
# 7   [{'accession': 'Q869C3', 'component_descriptio...     SINGLE PROTEIN
# 8   [{'accession': 'B3SST5', 'component_descriptio...     SINGLE PROTEIN
# 9   [{'accession': 'Q27677', 'component_descriptio...     SINGLE PROTEIN
# 10  [{'accession': 'Q9NJH6', 'component_descriptio...     SINGLE PROTEIN
# 11  [{'accession': 'P36196', 'component_descriptio...     SINGLE PROTEIN
# 12  [{'accession': 'Q9DDE3', 'component_descriptio...     SINGLE PROTEIN
# 13  [{'accession': 'Q6A2E2', 'component_descriptio...     SINGLE PROTEIN
# 14  [{'accession': 'O60888', 'component_descriptio...     SINGLE PROTEIN
# 15  [{'accession': 'Q95P20', 'component_descriptio...     SINGLE PROTEIN
# 16  [{'accession': 'Q8MZM0', 'component_descriptio...     SINGLE PROTEIN
# 17  [{'accession': 'Q7YWJ9', 'component_descriptio...     SINGLE PROTEIN
# 18  [{'accession': 'A2PZ98', 'component_descriptio...     SINGLE PROTEIN
# 19  [{'accession': 'C5IU80', 'component_descriptio...     SINGLE PROTEIN
# 20  [{'accession': 'K4JQ36', 'component_descriptio...     SINGLE PROTEIN
# 21  [{'accession': 'Q9BMJ1', 'component_descriptio...     SINGLE PROTEIN
# 22  [{'accession': 'P06276', 'component_descriptio...  SELECTIVITY GROUP
# 23  [{'accession': 'P37136', 'component_descriptio...  SELECTIVITY GROUP
# 24  [{'accession': 'P38433', 'component_descriptio...     SINGLE PROTEIN
# 25  [{'accession': 'Q9N1N9', 'component_descriptio...     SINGLE PROTEIN
# 26  [{'accession': 'P81908', 'component_descriptio...     SINGLE PROTEIN
# 27  [{'accession': 'P32750', 'component_descriptio...     SINGLE PROTEIN
# 28  [{'accession': 'Q03311', 'component_descriptio...     SINGLE PROTEIN
# 29  [{'accession': 'Q9JKC1', 'component_descriptio...     SINGLE PROTEIN
# 30  [{'accession': 'P06276', 'component_descriptio...     SINGLE PROTEIN
#
#     tax_id
# 0     7227
# 1     9606
# 2     7787
# 3    10090
# 4    10116
# 5     8005
# 6     9913
# 7     7165
# 8     7038
# 9     7539
# 10   94400
# 11    9031
# 12    7955
# 13    7159
# 14    9606
# 15    7370
# 16   51655
# 17    7370
# 18  121226
# 19   69820
# 20  195883
# 21   13262
# 22    9606
# 23   10116
# 24    6239
# 25    9796
# 26    9796
# 27    9615
# 28   10090
# 29   10116
# 30    9606

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Acetylcholinesterase* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Human Acetylcholinesterase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[5]
selected_target
# Out:
# 'CHEMBL4078'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Acetylcholinesterase* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = pd.DataFrame.from_dict(res)
#
# File c:\Users\ORippee\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:1926, in DataFrame.from_dict(cls, data, orient, dtype, columns)
#    1920     raise ValueError(
#    1921         f"Expected 'index', 'columns' or 'tight' for orient parameter. "
#    1922         f"Got '{orient}' instead"
#    1923     )
#    1925 if orient != "tight":
# -> 1926     return cls(data, index=index, columns=columns, dtype=dtype)
#    1927 else:
#    1928     realdata = data["data"]
#
# File c:\Users\ORippee\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:847, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     845         data = np.asarray(data)
#     846     else:
# --> 847         data = list(data)
#     848 if len(data) > 0:
#     849     if is_dataclass(data[0]):
#
# File c:\Users\ORippee\AppData\Local\anaconda3\Lib\site-packages\chembl_webresource_client\query_set.py:127, in QuerySet.__next__(self)
#     126 def __next__(self):
# --> 127     return self.next()
#
# File c:\Users\ORippee\AppData\Local\anaconda3\Lib\site-packages\chembl_webresource_client\query_set.py:115, in QuerySet.next(self)
#     113     self.chunk = self.query.get_page()
#     114 if not self.chunk or self.current_index >= len(self.chunk):
# --> 115     self.chunk = self.query.next_page()
#     116     if not self.chunk:
#     117         raise StopIteration
#
# File c:\Users\ORippee\AppData\Local\anaconda3\Lib\site-packages\chembl_webresource_client\url_query.py:434, in UrlQuery.next_page(self)
#     432 start = self.start
#     433 self.current_index = int(start + self.limit * (self.current_page + 1))
# --> 434 return self.get_page()
#
# File c:\Users\ORippee\AppData\Local\anaconda3\Lib\site-packages\chembl_webresource_client\url_query.py:389, in UrlQuery.get_page(self)
#     387 data = self._prepare_url_params()
#     388 with self._get_session() as session:
# --> 389     res = session.post(self.base_url + '.' + self.frmt, json=data, timeout=self.timeout)
#     390 self.logger.info(res.url)
#     391 self.logger.info(data)
#
# File c:\Users\ORippee\AppData\Local\anaconda3\Lib\site-packages\requests_cache\session.py:144, in CacheMixin.post(self, url, data, **kwargs)
#     143 def post(self, url: str, data=None, **kwargs) -> AnyResponse:  # type: ignore
# --> 144     return self.request('POST', url, data=data, **kwargs)
#
# File c:\Users\ORippee\AppData\Local\anaconda3\Lib\site-packages\requests_cache\session.py:189, in CacheMixin.request(self, method, url, headers, expire_after, only_if_cached, refresh, force_refresh, *args, **kwargs)
#     187 headers = set_request_headers(headers, expire_after, only_if_cached, refresh, force_refresh)
#     188 with patch_form_boundary() if kwargs.get('files') else nullcontext():
# --> 189     return super().request(method, url, *args, headers=headers, **kwargs)
#
# File c:\Users\ORippee\AppData\Local\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\ORippee\AppData\Local\anaconda3\Lib\site-packages\requests_cache\session.py:255, in CacheMixin.send(self, request, expire_after, only_if_cached, refresh, force_refresh, **kwargs)
#     253     response = self._resend(request, actions, cached_response, **kwargs)  # type: ignore
#     254 elif actions.send_request:
# --> 255     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#     256 else:
#     257     response = cached_response  # type: ignore  # Guaranteed to be non-None by this point
#
# File c:\Users\ORippee\AppData\Local\anaconda3\Lib\site-packages\requests_cache\session.py:279, in CacheMixin._send_and_cache(self, request, actions, cached_response, **kwargs)
#     275 """Send a request and cache the response, unless disabled by settings or headers.
#     276 If applicable, also handle conditional requests.
#     277 """
#     278 request = actions.update_request(request)
# --> 279 response = super().send(request, **kwargs)
#     280 actions.update_from_response(response)
#     282 if not actions.skip_write:
#
# File c:\Users\ORippee\AppData\Local\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\ORippee\AppData\Local\anaconda3\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File c:\Users\ORippee\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\ORippee\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\ORippee\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File c:\Users\ORippee\AppData\Local\anaconda3\Lib\site-packages\urllib3\connection.py:790, in HTTPSConnection.connect(self)
#     787     # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     788     server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 790     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     791         sock=sock,
#     792         cert_reqs=self.cert_reqs,
#     793         ssl_version=self.ssl_version,
#     794         ssl_minimum_version=self.ssl_minimum_version,
#     795         ssl_maximum_version=self.ssl_maximum_version,
#     796         ca_certs=self.ca_certs,
#     797         ca_cert_dir=self.ca_cert_dir,
#     798         ca_cert_data=self.ca_cert_data,
#     799         cert_file=self.cert_file,
#     800         key_file=self.key_file,
#     801         key_password=self.key_password,
#     802         server_hostname=server_hostname_rm_dot,
#     803         ssl_context=self.ssl_context,
#     804         tls_in_tls=tls_in_tls,
#     805         assert_hostname=self.assert_hostname,
#     806         assert_fingerprint=self.assert_fingerprint,
#     807     )
#     808     self.sock = sock_and_verified.socket
#     810 # If an error occurs during connection/handshake we may need to release
#     811 # our lock so another connection can probe the origin.
#
# File c:\Users\ORippee\AppData\Local\anaconda3\Lib\site-packages\urllib3\connection.py:969, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     966     if is_ipaddress(normalized):
#     967         server_hostname = normalized
# --> 969 ssl_sock = ssl_wrap_socket(
#     970     sock=sock,
#     971     keyfile=key_file,
#     972     certfile=cert_file,
#     973     key_password=key_password,
#     974     ca_certs=ca_certs,
#     975     ca_cert_dir=ca_cert_dir,
#     976     ca_cert_data=ca_cert_data,
#     977     server_hostname=server_hostname,
#     978     ssl_context=context,
#     979     tls_in_tls=tls_in_tls,
#     980 )
#     982 try:
#     983     if assert_fingerprint:
#
# File c:\Users\ORippee\AppData\Local\anaconda3\Lib\site-packages\urllib3\util\ssl_.py:458, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     456 if ca_certs or ca_cert_dir or ca_cert_data:
#     457     try:
# --> 458         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     459     except OSError as e:
#     460         raise SSLError(e) from e
#
# KeyboardInterrupt:

# %%
df
# Out:
#      activity_comment  activity_id  ... upper_value value
# 0                None        33969  ...        None  0.75
# 1                None        37563  ...        None   0.1
# 2                None        37565  ...        None  50.0
# 3                None        38902  ...        None   0.3
# 4                None        41170  ...        None   0.8
# ...               ...          ...  ...         ...   ...
# 7021             None     18798886  ...        None  3.81
# 7022             None     18798887  ...        None  3.46
# 7023             None     18798888  ...        None  2.78
# 7024             None     18798889  ...        None  0.45
# 7025             None     18798890  ...        None  2.51
#
# [7026 rows x 43 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('acetylcholinesterase_01_bioactivity_data_raw.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.to_csv('acetylcholinesterase_01_bioactivity_data_raw.csv', index=False)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df2 = df[df.standard_value.notna()]
#       2 df2 = df2[df.canonical_smiles.notna()]
#       3 df2
#
# NameError: name 'df' is not defined

# %%
len(df2.canonical_smiles.unique())
# Out:
# 4695

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#      activity_comment  activity_id  ... upper_value value
# 0                None        33969  ...        None  0.75
# 1                None        37563  ...        None   0.1
# 2                None        37565  ...        None  50.0
# 3                None        38902  ...        None   0.3
# 4                None        41170  ...        None   0.8
# ...               ...          ...  ...         ...   ...
# 7019             None     18798884  ...        None  2.44
# 7020             None     18798885  ...        None  2.54
# 7021             None     18798886  ...        None  3.81
# 7022             None     18798887  ...        None  3.46
# 7023             None     18798888  ...        None  2.78
#
# [4695 rows x 43 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id  ... standard_value
# 0          CHEMBL133897  ...          750.0
# 1          CHEMBL336398  ...          100.0
# 2          CHEMBL131588  ...        50000.0
# 3          CHEMBL130628  ...          300.0
# 4          CHEMBL130478  ...          800.0
# ...                 ...  ...            ...
# 7019      CHEMBL4293155  ...         2440.0
# 7020      CHEMBL4282558  ...         2540.0
# 7021      CHEMBL4281727  ...         3810.0
# 7022      CHEMBL4292349  ...         3460.0
# 7023      CHEMBL4278260  ...         2780.0
#
# [4695 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id  ...         class
# 0          CHEMBL133897  ...        active
# 1          CHEMBL336398  ...        active
# 2          CHEMBL131588  ...      inactive
# 3          CHEMBL130628  ...        active
# 4          CHEMBL130478  ...        active
# ...                 ...  ...           ...
# 4690      CHEMBL4293155  ...  intermediate
# 4691      CHEMBL4282558  ...  intermediate
# 4692      CHEMBL4281727  ...  intermediate
# 4693      CHEMBL4292349  ...  intermediate
# 4694      CHEMBL4278260  ...  intermediate
#
# [4695 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('acetylcholinesterase_03_bioactivity_data_curated.csv', index=False)

# %%
! zip acetylcholinesterase.zip *.csv
# Out:
#   adding: acetylcholinesterase_01_bioactivity_data_raw.csv (deflated 90%)
#   adding: acetylcholinesterase_02_bioactivity_data_preprocessed.csv (deflated 81%)
#   adding: acetylcholinesterase_03_bioactivity_data_curated.csv (deflated 82%)

# %%
! ls -l
# Out:
# total 4668
# -rw-r--r-- 1 root root 3562870 Jun  1 15:03 acetylcholinesterase_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  342989 Jun  1 15:03 acetylcholinesterase_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  385924 Jun  1 15:03 acetylcholinesterase_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  475843 Jun  1 15:03 acetylcholinesterase.zip
# drwxr-xr-x 1 root root    4096 May 27 16:27 sample_data

# %% [markdown]
# ---
